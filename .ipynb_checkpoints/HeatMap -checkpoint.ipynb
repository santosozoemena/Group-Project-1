# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
with open("city_sentiments.csv") as sentiments:
    heat_df = pd.read_csv(sentiments)
    
heat_df = heat_df[['Restaurant Names',
                               'Chicago', 
                               'New York', 
                               'Houston',
                               'Philadelphia',
                               'Los Angeles',
                               'Atlanta',
                               'Miami']]
heat_df
# Out:
#         Restaurant Names   Chicago  New York   Houston  Philadelphia  \
# 0            Red Lobster  0.396564  0.394859  0.393194      0.391567
# 1     SUBWAY®Restaurants  0.213683  0.211380  0.209100      0.206844
# 2        In-N-Out Burger  0.218667  0.220409  0.222136      0.223848
# 3   Little Caesars Pizza  0.198930  0.198147  0.197370      0.196599
# 4    Chili's Grill & Bar  0.198746  0.198182  0.197620      0.197062
# 5              Fatburger  0.210512  0.210741  0.210969      0.211195
# 6               Wingstop  0.163071  0.162729  0.162390      0.162051
# 7      Chuck E. Cheese's  0.163424  0.164005  0.164583      0.165160
# 8            TGI Fridays  0.151398  0.151126  0.150854      0.150583
# 9               Benihana  0.136453  0.136247  0.136040      0.135835
# 10          Olive Garden  0.119471  0.119483  0.119495      0.119508
# 11             Taco Bell  0.164135  0.164916  0.165695      0.166471
# 12              Jack Box  0.181137  0.181607  0.182075      0.182543
# ...

# %%
heat_df.shape
# Out:
# (20, 8)

# %%
heat_df.columns
# Out:
# Index(['Restaurant Names', 'Chicago', 'New York', 'Houston', 'Philadelphia',
#        'Los Angeles', 'Atlanta', 'Miami'],
#       dtype='object')

# %%
chicago_df = heat_df[["Restaurant Names", "Chicago"]]
chicago_df
# Out:
#         Restaurant Names   Chicago
# 0            Red Lobster  0.396564
# 1     SUBWAY®Restaurants  0.213683
# 2        In-N-Out Burger  0.218667
# 3   Little Caesars Pizza  0.198930
# 4    Chili's Grill & Bar  0.198746
# 5              Fatburger  0.210512
# 6               Wingstop  0.163071
# 7      Chuck E. Cheese's  0.163424
# 8            TGI Fridays  0.151398
# 9               Benihana  0.136453
# 10          Olive Garden  0.119471
# 11             Taco Bell  0.164135
# 12              Jack Box  0.181137
# 13               Wendy's  0.167351
# 14            McDonald's  0.133516
# 15       Popeyes Chicken  0.119029
# 16          Panera Bread  0.115975
# 17             Starbucks  0.110474
# 18           Burger King  0.107483
# 19            Applebee's  0.105764

# %%
chicago_df.pivot('Restaurant Names', 'Chicago').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Applebee's, Benihana, Burger King, Chili's Grill & Bar, Chuck E. Cheese's]

# %%
# chicago_group = chicago_df.groupby(["Restaurant Names"]).mean()

# print(chicago_group.shape)
# Out:
# (20, 1)

# %%
# Out:
#                       Chicago
# Restaurant Names
# Applebee's           0.105764
# Benihana             0.136453
# Burger King          0.107483
# Chili's Grill & Bar  0.198746
# Chuck E. Cheese's    0.163424

# %%
plt.figure(figsize=(20,8))
pivot_table = chicago_group("Restaurant Names", "Chicago")
plt.xlabel('Chicago', size = 15)
plt.ylabel('Restaurant Names', size = 15)
plt.title(' ', size = 15)
sns.heatmap(pivot_table, annot=True, fmt=".1f", linewidths=.5, square = True, cmap = 'Blues_r');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-59ad7b967d61> in <module>()
#       1 plt.figure(figsize=(20,8))
# ----> 2 pivot_table = chicago_group("Restaurant Names", "Chicago")
#       3 plt.xlabel('Chicago', size = 15)
#       4 plt.ylabel('Restaurant Names', size = 15)
#       5 plt.title(' ', size = 15)
#
# TypeError: 'DataFrame' object is not callable
