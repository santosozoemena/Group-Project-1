# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import tweepy
import requests as rq
import json
import matplotlib.pyplot as plt
import seaborn as sns

from yelp.client import Client
from tweepy.parsers import JSONParser
from geopy.geocoders import Nominatim
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

geolocator = Nominatim()
analyzer = SentimentIntensityAnalyzer()

consumer_key = "Ed4RNulN1lp7AbOooHa9STCoU"
consumer_secret = "P7cUJlmJZq0VaCY0Jg7COliwQqzK0qYEyUF9Y0idx4ujb3ZlW5"
access_token = "839621358724198402-dzdOsx2WWHrSuBwyNUiqSEnTivHozAZ"
access_token_secret = "dCZ80uNRbFDjxdU2EckmNiSckdoATach6Q8zb7YYYE5ER"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=JSONParser())

target_cities = ["Chicago",
                 "New York"]

# %%
coordinates = []
for city in target_cities:
    location = geolocator.geocode(city)
    coordinates.append({"Latitude": location.latitude,
                        "Longitude": location.longitude,
                        "City": city})
    
coordinates_df = pd.DataFrame.from_dict(coordinates)
coordinates_df = coordinates_df.set_index("City", inplace = False)

# %%
coordinates_df.to_csv("city_coordinates_dataframe.csv")

# %%
coordinates_data = pd.read_csv("city_coordinates_dataframe.csv")



for index, row in coordinates_data.iterrows():
    geo_code = ('%s,%s,20mi' %(row["Latitude"],row["Longitude"]))
    
    
    geo_coordinates = []
    geo_coordinates.append(geo_code)
        

    print(geo_coordinates)
    
    sentiment_df = pd.read_csv("LA-restaurant.csv")
    
    compound_list = []
    compound_heat = []
    for index, row in sentiment_df.iterrows():
        public_tweets = api.search(row["User Name"], rpp=100, result_type="recent", geocode = geo_coordinates[0])   
  
        
        
        for tweet in public_tweets["statuses"]:
            raw_time = []
        
            for element in target_cities:
                compound = analyzer.polarity_scores(tweet["text"])["compound"]
                raw_time.append(tweet["created_at"])
               
                compound_heat.append({'Compound_Sentiment' : compound,
                                      'Restaurant': row["User Name"],
                                      'Time': raw_time,
                                      'City' : element})
                
                compound_list.append(compound)
                sentiments_heat = pd.DataFrame.from_dict(compound_heat)
                sentiment_df.set_value(index, element, np.mean(compound_list))
# Out:
# ['41.8755546,-87.6244212,20mi']
# ['40.7306458,-73.9866136,20mi']

# %%
sentiment_df = sentiment_df.dropna()
del sentiment_df['Unnamed: 0']

# %%
sentiment_df
# Out:
#         Restaurant Names       User Name  Follower Count   Chicago  New York
# 0            Red Lobster      redlobster          296664  0.609434  0.589120
# 1     SUBWAY®Restaurants          SUBWAY         2467427  0.377846  0.361133
# 3        In-N-Out Burger    innoutburger           44775  0.246362  0.243624
# 6   Little Caesars Pizza   littlecaesars          232112  0.192771  0.193291
# 8    Chili's Grill & Bar          Chilis          383907  0.227268  0.228921
# 9              Fatburger       Fatburger           14993  0.198937  0.197662
# 10              Wingstop        wingstop          208253  0.135323  0.134596
# 11     Chuck E. Cheese's   ChuckECheeses           23749  0.131009  0.131623
# 12           TGI Fridays      TGIFridays          208950  0.136323  0.135686
# 14              Benihana        Benihana           13086  0.055218  0.051916
# 15          Olive Garden     olivegarden          385774  0.047597  0.047423
# 16             Taco Bell        tacobell         1888502  0.046117  0.045965
# 17              Jack Box         JackBox           91621  0.059556  0.059378
# 18               Wendy's          Wendys         2288957  0.060146  0.060401
# 19            McDonald's       McDonalds         3540391  0.063862  0.063699
# 20       Popeyes Chicken  PopeyesChicken           92760  0.032121  0.030443
# 21          Panera Bread       askpanera             563  0.036657  0.037622
# 22             Starbucks       Starbucks        11942459  0.039924  0.039478
# 23           Burger King      BurgerKing         1591887  0.037249  0.037173
# 24            Applebee's       Applebees          627246  0.036621  0.036307

# %%
sentiment_df.to_csv("city_sentiments.csv")

# %%
sentiment_heat = pd.DataFrame(compound_heat)
sentiment_heat = sentiment_heat.loc[sentiment_heat["Compound_Sentiment"] != 0]
sentiment_heat
# Out:
#          City  Compound_Sentiment  Restaurant  \
# 0     Chicago              0.6996  redlobster
# 1    New York              0.6996  redlobster
# 2     Chicago              0.6996  redlobster
# 3    New York              0.6996  redlobster
# 4     Chicago              0.6996  redlobster
# 5    New York              0.6996  redlobster
# 6     Chicago              0.6996  redlobster
# 7    New York              0.6996  redlobster
# 10    Chicago              0.9204  redlobster
# 11   New York              0.9204  redlobster
# 12    Chicago              0.9204  redlobster
# 13   New York              0.9204  redlobster
# 14    Chicago              0.6996  redlobster
# 15   New York              0.6996  redlobster
# 16    Chicago              0.6996  redlobster
# 17   New York              0.6996  redlobster
# 18    Chicago              0.6996  redlobster
# 19   New York              0.6996  redlobster
# 20    Chicago              0.6996  redlobster
# 21   New York              0.6996  redlobster
# 24    Chicago              0.6996  redlobster
# 25   New York              0.6996  redlobster
# 26    Chicago              0.6996  redlobster
# 27   New York              0.6996  redlobster
# 38    Chicago              0.6696      SUBWAY
# 39   New York              0.6696      SUBWAY
# 42    Chicago              0.2732      SUBWAY
# 43   New York              0.2732      SUBWAY
# 44    Chicago              0.6388      SUBWAY
# 45   New York              0.6388      SUBWAY
# ..        ...                 ...         ...
# 468   Chicago             -0.5362  BurgerKing
# 469  New York             -0.5362  BurgerKing
# 470   Chicago             -0.4404  BurgerKing
# 471  New York             -0.4404  BurgerKing
# 472   Chicago              0.8074  BurgerKing
# 473  New York              0.8074  BurgerKing
# 474   Chicago             -0.7251  BurgerKing
# 475  New York             -0.7251  BurgerKing
# 484   Chicago              0.8074  BurgerKing
# 485  New York              0.8074  BurgerKing
# 488   Chicago              0.5574   Applebees
# 489  New York              0.5574   Applebees
# 490   Chicago             -0.5423   Applebees
# 491  New York             -0.5423   Applebees
# 496   Chicago             -0.4019   Applebees
# 497  New York             -0.4019   Applebees
# 498   Chicago              0.7096   Applebees
# 499  New York              0.7096   Applebees
# 500   Chicago             -0.4003   Applebees
# 501  New York             -0.4003   Applebees
# 502   Chicago             -0.1263   Applebees
# 503  New York             -0.1263   Applebees
# 506   Chicago              0.0772   Applebees
# 507  New York              0.0772   Applebees
# 508   Chicago              0.7125   Applebees
# 509  New York              0.7125   Applebees
# 512   Chicago             -0.1263   Applebees
# 513  New York             -0.1263   Applebees
# 516   Chicago             -0.1263   Applebees
# 517  New York             -0.1263   Applebees
#
#                                                   Time
# 0    [Fri Jan 19 16:04:14 +0000 2018, Fri Jan 19 16...
# 1    [Fri Jan 19 16:04:14 +0000 2018, Fri Jan 19 16...
# 2    [Fri Jan 19 16:04:09 +0000 2018, Fri Jan 19 16...
# 3    [Fri Jan 19 16:04:09 +0000 2018, Fri Jan 19 16...
# 4    [Fri Jan 19 16:01:28 +0000 2018, Fri Jan 19 16...
# 5    [Fri Jan 19 16:01:28 +0000 2018, Fri Jan 19 16...
# 6    [Fri Jan 19 14:44:39 +0000 2018, Fri Jan 19 14...
# 7    [Fri Jan 19 14:44:39 +0000 2018, Fri Jan 19 14...
# 10   [Fri Jan 19 12:43:53 +0000 2018, Fri Jan 19 12...
# 11   [Fri Jan 19 12:43:53 +0000 2018, Fri Jan 19 12...
# 12   [Fri Jan 19 12:31:10 +0000 2018, Fri Jan 19 12...
# 13   [Fri Jan 19 12:31:10 +0000 2018, Fri Jan 19 12...
# 14   [Fri Jan 19 12:22:12 +0000 2018, Fri Jan 19 12...
# 15   [Fri Jan 19 12:22:12 +0000 2018, Fri Jan 19 12...
# 16   [Fri Jan 19 11:26:00 +0000 2018, Fri Jan 19 11...
# 17   [Fri Jan 19 11:26:00 +0000 2018, Fri Jan 19 11...
# 18   [Fri Jan 19 04:49:06 +0000 2018, Fri Jan 19 04...
# 19   [Fri Jan 19 04:49:06 +0000 2018, Fri Jan 19 04...
# 20   [Fri Jan 19 03:53:16 +0000 2018, Fri Jan 19 03...
# 21   [Fri Jan 19 03:53:16 +0000 2018, Fri Jan 19 03...
# 24   [Fri Jan 19 03:09:57 +0000 2018, Fri Jan 19 03...
# 25   [Fri Jan 19 03:09:57 +0000 2018, Fri Jan 19 03...
# 26   [Fri Jan 19 02:49:16 +0000 2018, Fri Jan 19 02...
# 27   [Fri Jan 19 02:49:16 +0000 2018, Fri Jan 19 02...
# 38   [Fri Jan 19 17:40:36 +0000 2018, Fri Jan 19 17...
# 39   [Fri Jan 19 17:40:36 +0000 2018, Fri Jan 19 17...
# 42   [Fri Jan 19 17:37:01 +0000 2018, Fri Jan 19 17...
# 43   [Fri Jan 19 17:37:01 +0000 2018, Fri Jan 19 17...
# 44   [Fri Jan 19 17:36:26 +0000 2018, Fri Jan 19 17...
# 45   [Fri Jan 19 17:36:26 +0000 2018, Fri Jan 19 17...
# ..                                                 ...
# 468  [Fri Jan 19 03:04:05 +0000 2018, Fri Jan 19 03...
# 469  [Fri Jan 19 03:04:05 +0000 2018, Fri Jan 19 03...
# 470  [Fri Jan 19 02:12:28 +0000 2018, Fri Jan 19 02...
# 471  [Fri Jan 19 02:12:28 +0000 2018, Fri Jan 19 02...
# 472  [Fri Jan 19 00:34:37 +0000 2018, Fri Jan 19 00...
# 473  [Fri Jan 19 00:34:37 +0000 2018, Fri Jan 19 00...
# 474  [Thu Jan 18 22:06:59 +0000 2018, Thu Jan 18 22...
# 475  [Thu Jan 18 22:06:59 +0000 2018, Thu Jan 18 22...
# 484  [Thu Jan 18 19:15:17 +0000 2018, Thu Jan 18 19...
# 485  [Thu Jan 18 19:15:17 +0000 2018, Thu Jan 18 19...
# 488  [Fri Jan 19 17:31:06 +0000 2018, Fri Jan 19 17...
# 489  [Fri Jan 19 17:31:06 +0000 2018, Fri Jan 19 17...
# 490  [Fri Jan 19 15:52:39 +0000 2018, Fri Jan 19 15...
# 491  [Fri Jan 19 15:52:39 +0000 2018, Fri Jan 19 15...
# 496  [Fri Jan 19 14:10:26 +0000 2018, Fri Jan 19 14...
# 497  [Fri Jan 19 14:10:26 +0000 2018, Fri Jan 19 14...
# 498  [Fri Jan 19 14:01:01 +0000 2018, Fri Jan 19 14...
# 499  [Fri Jan 19 14:01:01 +0000 2018, Fri Jan 19 14...
# 500  [Fri Jan 19 13:35:11 +0000 2018, Fri Jan 19 13...
# 501  [Fri Jan 19 13:35:11 +0000 2018, Fri Jan 19 13...
# 502  [Fri Jan 19 07:20:34 +0000 2018, Fri Jan 19 07...
# 503  [Fri Jan 19 07:20:34 +0000 2018, Fri Jan 19 07...
# 506  [Fri Jan 19 02:39:47 +0000 2018, Fri Jan 19 02...
# 507  [Fri Jan 19 02:39:47 +0000 2018, Fri Jan 19 02...
# 508  [Fri Jan 19 02:31:10 +0000 2018, Fri Jan 19 02...
# 509  [Fri Jan 19 02:31:10 +0000 2018, Fri Jan 19 02...
# 512  [Fri Jan 19 01:26:01 +0000 2018, Fri Jan 19 01...
# 513  [Fri Jan 19 01:26:01 +0000 2018, Fri Jan 19 01...
# 516  [Thu Jan 18 23:45:19 +0000 2018, Thu Jan 18 23...
# 517  [Thu Jan 18 23:45:19 +0000 2018, Thu Jan 18 23...
#
# [296 rows x 4 columns]

# %%
sentiment_heat = sentiment_heat.groupby(['Restaurant', 'Time']).mean()
sentiment_heat = sentiment_heat.reset_index()
sentiment_heat
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _cython_agg_blocks(self, how, alt, numeric_only)
#    3396                 result, _ = self.grouper.aggregate(
# -> 3397                     block.values, how, axis=agg_axis)
#    3398             except NotImplementedError:
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in aggregate(self, values, how, axis)
#    2135     def aggregate(self, values, how, axis=0):
# -> 2136         return self._cython_operation('aggregate', values, how, axis)
#    2137
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _cython_operation(self, kind, values, how, axis)
#    2047                                           "supported for the 'how' argument")
# -> 2048             out_shape = (self.ngroups,) + values.shape[1:]
#    2049
#
# pandas/_libs/src\properties.pyx in pandas._libs.lib.cache_readonly.__get__()
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in ngroups(self)
#    1890     def ngroups(self):
# -> 1891         return len(self.result_index)
#    1892
#
# pandas/_libs/src\properties.pyx in pandas._libs.lib.cache_readonly.__get__()
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in result_index(self)
#    1904
# -> 1905         return MultiIndex(levels=[ping.group_index for ping in self.groupings],
#    1906                           labels=self.recons_labels,
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in <listcomp>(.0)
#    1904
# -> 1905         return MultiIndex(levels=[ping.group_index for ping in self.groupings],
#    1906                           labels=self.recons_labels,
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in group_index(self)
#    2538         if self._group_index is None:
# -> 2539             self._make_labels()
#    2540         return self._group_index
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _make_labels(self)
#    2544             labels, uniques = algorithms.factorize(
# -> 2545                 self.grouper, sort=self.sort)
#    2546             uniques = Index(uniques, name=self.name)
#
# ~\Anaconda\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     559     check_nulls = not is_integer_dtype(original)
# --> 560     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     561
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1036         try:
# -> 1037             return self._cython_agg_general('mean', **kwargs)
#    1038         except GroupByError:
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, alt, numeric_only)
#    3353         new_items, new_blocks = self._cython_agg_blocks(
# -> 3354             how, alt=alt, numeric_only=numeric_only)
#    3355         return self._wrap_agged_blocks(new_items, new_blocks)
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _cython_agg_blocks(self, how, alt, numeric_only)
#    3417                 # see if we can cast the block back to the original dtype
# -> 3418                 result = block._try_coerce_and_cast_result(result)
#    3419                 newb = block.make_block(result)
#
# UnboundLocalError: local variable 'result' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-86ed0ee8d246> in <module>()
# ----> 1 sentiment_heat = sentiment_heat.groupby(['Restaurant', 'Time']).mean()
#       2 sentiment_heat = sentiment_heat.reset_index()
#       3 sentiment_heat
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1041             self._set_group_selection()
#    1042             f = lambda x: x.mean(axis=self.axis, **kwargs)
# -> 1043             return self._python_agg_general(f)
#    1044
#    1045     @Substitution(name='groupby')
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     852
#     853         if len(output) == 0:
# --> 854             return self._python_apply_general(f)
#     855
#     856         if self.grouper._filter_empty_groups:
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _python_apply_general(self, f)
#     718     def _python_apply_general(self, f):
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 720                                                    self.axis)
#     721
#     722         return self._wrap_applied_output(
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in apply(self, f, data, axis)
#    1776     def apply(self, f, data, axis=0):
#    1777         mutated = self.mutated
# -> 1778         splitter = self._get_splitter(data, axis=axis)
#    1779         group_keys = self._get_group_keys()
#    1780
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _get_splitter(self, data, axis)
#    1759
#    1760     def _get_splitter(self, data, axis=0):
# -> 1761         comp_ids, _, ngroups = self.group_info
#    1762         return get_splitter(data, comp_ids, ngroups, axis=axis)
#    1763
#
# pandas/_libs/src\properties.pyx in pandas._libs.lib.cache_readonly.__get__()
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in group_info(self)
#    1871     @cache_readonly
#    1872     def group_info(self):
# -> 1873         comp_ids, obs_group_ids = self._get_compressed_labels()
#    1874
#    1875         ngroups = len(obs_group_ids)
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _get_compressed_labels(self)
#    1878
#    1879     def _get_compressed_labels(self):
# -> 1880         all_labels = [ping.labels for ping in self.groupings]
#    1881         if len(all_labels) > 1:
#    1882             group_index = get_group_index(all_labels, self.shape,
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in <listcomp>(.0)
#    1878
#    1879     def _get_compressed_labels(self):
# -> 1880         all_labels = [ping.labels for ping in self.groupings]
#    1881         if len(all_labels) > 1:
#    1882             group_index = get_group_index(all_labels, self.shape,
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in labels(self)
#    2531     def labels(self):
#    2532         if self._labels is None:
# -> 2533             self._make_labels()
#    2534         return self._labels
#    2535
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby.py in _make_labels(self)
#    2543         if self._labels is None or self._group_index is None:
#    2544             labels, uniques = algorithms.factorize(
# -> 2545                 self.grouper, sort=self.sort)
#    2546             uniques = Index(uniques, name=self.name)
#    2547             self._labels = labels
#
# ~\Anaconda\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     558     uniques = vec_klass()
#     559     check_nulls = not is_integer_dtype(original)
# --> 560     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     561
#     562     labels = _ensure_platform_int(labels)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# TypeError: unhashable type: 'list'

# %%
sentiment_heat = sentiment_heat.pivot('Restaurant', 'Time', 'Compound_Sentiment')

sentiment_heat
# Out:
# Time            Fri Jan 12 03:19:38 +0000 2018  \
# Restaurant
# Applebees                                0.000
# Benihana                                 0.000
# BurgerKing                               0.000
# Chilis                                   0.000
# ChuckECheeses                            0.000
# Fatburger                                0.296
# JackBox                                  0.000
# McDonalds                                0.000
# PopeyesChicken                           0.000
# SUBWAY                                   0.000
# Starbucks                                0.000
# TGIFridays                               0.000
# Wendys                                   0.000
# askpanera                                0.000
# innoutburger                             0.000
# littlecaesars                            0.000
# olivegarden                              0.000
# redlobster                               0.000
# tacobell                                 0.000
# wingstop                                 0.000
#
# Time            Fri Jan 12 03:20:31 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.6369
# JackBox                                 0.0000
# McDonalds                               0.0000
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time            Fri Jan 12 03:24:26 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.5423
# JackBox                                 0.0000
# McDonalds                               0.0000
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time            Fri Jan 12 10:02:51 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.0000
# JackBox                                 0.0000
# McDonalds                               0.0000
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.5719
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time            Fri Jan 12 11:37:09 +0000 2018  \
# Restaurant
# Applebees                                  0.0
# Benihana                                   0.0
# BurgerKing                                 0.0
# Chilis                                     0.0
# ChuckECheeses                              0.0
# Fatburger                                  0.0
# JackBox                                    0.0
# McDonalds                                  0.0
# PopeyesChicken                             0.0
# SUBWAY                                     0.0
# Starbucks                                  0.0
# TGIFridays                                 0.0
# Wendys                                     0.0
# askpanera                                  0.0
# innoutburger                               0.0
# littlecaesars                              0.0
# olivegarden                                0.0
# redlobster                                 0.0
# tacobell                                   0.0
# wingstop                                   0.0
#
# Time            Fri Jan 12 11:57:01 +0000 2018  \
# Restaurant
# Applebees                                  0.0
# Benihana                                   0.0
# BurgerKing                                 0.0
# Chilis                                     0.0
# ChuckECheeses                              0.0
# Fatburger                                  0.0
# JackBox                                    0.0
# McDonalds                                  0.0
# PopeyesChicken                             0.0
# SUBWAY                                     0.0
# Starbucks                                  0.0
# TGIFridays                                 0.0
# Wendys                                     0.0
# askpanera                                  0.0
# innoutburger                               0.0
# littlecaesars                              0.0
# olivegarden                                0.0
# redlobster                                 0.0
# tacobell                                   0.0
# wingstop                                   0.0
#
# Time            Fri Jan 12 12:51:27 +0000 2018  \
# Restaurant
# Applebees                                  0.0
# Benihana                                   0.0
# BurgerKing                                 0.0
# Chilis                                     0.0
# ChuckECheeses                              0.0
# Fatburger                                  0.0
# JackBox                                    0.0
# McDonalds                                  0.0
# PopeyesChicken                             0.0
# SUBWAY                                     0.0
# Starbucks                                  0.0
# TGIFridays                                 0.0
# Wendys                                     0.0
# askpanera                                  0.0
# innoutburger                               0.0
# littlecaesars                              0.0
# olivegarden                                0.0
# redlobster                                 0.0
# tacobell                                   0.0
# wingstop                                   0.0
#
# Time            Fri Jan 12 16:12:21 +0000 2018  \
# Restaurant
# Applebees                                  0.0
# Benihana                                   0.0
# BurgerKing                                 0.0
# Chilis                                     0.0
# ChuckECheeses                              0.0
# Fatburger                                  0.0
# JackBox                                    0.0
# McDonalds                                  0.0
# PopeyesChicken                             0.0
# SUBWAY                                     0.0
# Starbucks                                  0.0
# TGIFridays                                 0.0
# Wendys                                     0.0
# askpanera                                  0.0
# innoutburger                               0.0
# littlecaesars                              0.0
# olivegarden                                0.0
# redlobster                                 0.0
# tacobell                                   0.0
# wingstop                                   0.0
#
# Time            Fri Jan 12 17:26:16 +0000 2018  \
# Restaurant
# Applebees                                  0.0
# Benihana                                   0.0
# BurgerKing                                 0.0
# Chilis                                     0.0
# ChuckECheeses                              0.0
# Fatburger                                  0.0
# JackBox                                    0.0
# McDonalds                                  0.0
# PopeyesChicken                             0.0
# SUBWAY                                     0.0
# Starbucks                                  0.0
# TGIFridays                                 0.0
# Wendys                                     0.0
# askpanera                                  0.0
# innoutburger                               0.0
# littlecaesars                              0.0
# olivegarden                                0.0
# redlobster                                 0.0
# tacobell                                   0.0
# wingstop                                   0.0
#
# Time            Fri Jan 12 17:45:00 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.3612
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.0000
# JackBox                                 0.0000
# McDonalds                               0.0000
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time                         ...                \
# Restaurant                   ...
# Applebees                    ...
# Benihana                     ...
# BurgerKing                   ...
# Chilis                       ...
# ChuckECheeses                ...
# Fatburger                    ...
# JackBox                      ...
# McDonalds                    ...
# PopeyesChicken               ...
# SUBWAY                       ...
# Starbucks                    ...
# TGIFridays                   ...
# Wendys                       ...
# askpanera                    ...
# innoutburger                 ...
# littlecaesars                ...
# olivegarden                  ...
# redlobster                   ...
# tacobell                     ...
# wingstop                     ...
#
# Time            Wed Jan 17 23:34:20 +0000 2018  \
# Restaurant
# Applebees                                  0.0
# Benihana                                   0.0
# BurgerKing                                 0.0
# Chilis                                     0.0
# ChuckECheeses                              0.0
# Fatburger                                  0.0
# JackBox                                    0.0
# McDonalds                                  0.0
# PopeyesChicken                             0.0
# SUBWAY                                     0.0
# Starbucks                                  0.0
# TGIFridays                                 0.0
# Wendys                                     0.0
# askpanera                                  0.0
# innoutburger                               0.0
# littlecaesars                              0.0
# olivegarden                                0.0
# redlobster                                 0.0
# tacobell                                   0.0
# wingstop                                   0.0
#
# Time            Wed Jan 17 23:41:17 +0000 2018  \
# Restaurant
# Applebees                                0.000
# Benihana                                 0.000
# BurgerKing                               0.000
# Chilis                                   0.000
# ChuckECheeses                            0.000
# Fatburger                                0.000
# JackBox                                  0.000
# McDonalds                                0.841
# PopeyesChicken                           0.000
# SUBWAY                                   0.000
# Starbucks                                0.000
# TGIFridays                               0.000
# Wendys                                   0.000
# askpanera                                0.000
# innoutburger                             0.000
# littlecaesars                            0.000
# olivegarden                              0.000
# redlobster                               0.000
# tacobell                                 0.000
# wingstop                                 0.000
#
# Time            Wed Jan 17 23:41:32 +0000 2018  \
# Restaurant
# Applebees                                  0.0
# Benihana                                   0.0
# BurgerKing                                 0.0
# Chilis                                     0.0
# ChuckECheeses                              0.0
# Fatburger                                  0.0
# JackBox                                    0.0
# McDonalds                                  0.0
# PopeyesChicken                             0.0
# SUBWAY                                     0.0
# Starbucks                                  0.0
# TGIFridays                                 0.0
# Wendys                                     0.0
# askpanera                                  0.0
# innoutburger                               0.0
# littlecaesars                              0.0
# olivegarden                                0.0
# redlobster                                 0.0
# tacobell                                   0.0
# wingstop                                   0.0
#
# Time            Wed Jan 17 23:41:47 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.0000
# JackBox                                 0.0000
# McDonalds                               0.6486
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time            Wed Jan 17 23:42:13 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.0000
# JackBox                                 0.0000
# McDonalds                              -0.1531
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time            Wed Jan 17 23:42:53 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.0000
# JackBox                                 0.0000
# McDonalds                              -0.6113
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time            Wed Jan 17 23:43:21 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.0000
# JackBox                                 0.0000
# McDonalds                               0.0000
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.7777
# wingstop                                0.0000
#
# Time            Wed Jan 17 23:43:30 +0000 2018  \
# Restaurant
# Applebees                               0.0000
# Benihana                                0.0000
# BurgerKing                              0.0000
# Chilis                                  0.0000
# ChuckECheeses                           0.0000
# Fatburger                               0.0000
# JackBox                                 0.0000
# McDonalds                               0.8016
# PopeyesChicken                          0.0000
# SUBWAY                                  0.0000
# Starbucks                               0.0000
# TGIFridays                              0.0000
# Wendys                                  0.0000
# askpanera                               0.0000
# innoutburger                            0.0000
# littlecaesars                           0.0000
# olivegarden                             0.0000
# redlobster                              0.0000
# tacobell                                0.0000
# wingstop                                0.0000
#
# Time            Wed Jan 17 23:44:13 +0000 2018  Wed Jan 17 23:45:20 +0000 2018
# Restaurant
# Applebees                                  0.0                          0.0000
# Benihana                                   0.0                          0.0000
# BurgerKing                                 0.0                          0.0000
# Chilis                                     0.0                          0.0000
# ChuckECheeses                              0.0                          0.0000
# Fatburger                                  0.0                          0.0000
# JackBox                                    0.0                          0.0000
# McDonalds                                  0.0                          0.0000
# PopeyesChicken                             0.0                          0.0000
# SUBWAY                                     0.0                         -0.7916
# Starbucks                                  0.0                          0.0000
# TGIFridays                                 0.0                          0.0000
# Wendys                                     0.0                          0.0000
# askpanera                                  0.0                          0.0000
# innoutburger                               0.0                          0.0000
# littlecaesars                              0.0                          0.0000
# olivegarden                                0.0                          0.0000
# redlobster                                 0.0                          0.0000
# tacobell                                   0.0                          0.0000
# wingstop                                   0.0                          0.0000
#
# [20 rows x 203 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (25,25))

sns.heatmap(sentiment_heat, linewidth = 0.9)

plt.show()
