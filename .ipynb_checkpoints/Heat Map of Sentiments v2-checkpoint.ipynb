# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


with open("city_sentiments.csv") as sentiments:
    avg_sentiment = pd.read_csv(sentiments)
    
avg_sentiment = avg_sentiment[['Chicago', 
                               'New York', 
                               'Houston',
                               'Philadelphia',
                               'Los Angeles',
                               'Atlanta',
                               'Miami']]

avg_sentiment
# Out:
#      Chicago  New York   Houston  Philadelphia  Los Angeles   Atlanta  \
# 0   0.396564  0.394859  0.393194      0.391567     0.389976  0.388421
# 1   0.213683  0.211380  0.209100      0.206844     0.204611  0.202402
# 2   0.218667  0.220409  0.222136      0.223848     0.225545  0.227227
# 3   0.198930  0.198147  0.197370      0.196599     0.195834  0.195075
# 4   0.198746  0.198182  0.197620      0.197062     0.196507  0.195955
# 5   0.210512  0.210741  0.210969      0.211195     0.211421  0.211645
# 6   0.163071  0.162729  0.162390      0.162051     0.161715  0.161379
# 7   0.163424  0.164005  0.164583      0.165160     0.165734  0.166306
# 8   0.151398  0.151126  0.150854      0.150583     0.150313  0.150044
# 9   0.136453  0.136247  0.136040      0.135835     0.135630  0.135426
# 10  0.119471  0.119483  0.119495      0.119508     0.119520  0.119532
# 11  0.164135  0.164916  0.165695      0.166471     0.167246  0.168019
# ...

# %%
x_axis = np.arange(len(target_cities))
sns.set()


target_cities = ["Chicago",
                 "New York",
                 "Houston",
                 "Philadelphia",
                 "Los Angeles",
                 "Atlanta",
                 "Miami"]

x_axis = np.arange(len(target_cities))
sns.set()

color_scheme = ["darkred",
                "darkorange",
                "gold",
                "black",
                "darkblue",
                "darkgreen",
                "darkviolet"]


avg_list = []
for city in target_cities:
    avg_list.append(avg_sentiment[city].mean())
    

    for color_choice in color_scheme:
        sentiment_analysis = plt.bar(x_axis,
                                     avg_list,
                                     color = {color_choice})

        tick_locations = [value for value in x_axis]
        

    
    
    
avg_sentiment_df = pd.DataFrame.from_dict(avg_list)
avg_sentiment_df
