# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


with open("city_sentiments.csv") as sentiments:
    avg_sentiment = pd.read_csv(sentiments)
    
avg_sentiment = avg_sentiment[["Miami",
                 "New York",
                 "Los Angeles",
                 "Philadelphia",
                 "Houston",
                 "Atlanta",
                 "Chicago"]]

avg_sentiment
# Out:
#        Miami  New York  Los Angeles  Philadelphia   Houston   Atlanta  \
# 0   0.276150  0.257400     0.268884      0.265137  0.261310  0.272555
# 1   0.139069  0.142581     0.140453      0.141155  0.141864  0.139757
# 2   0.175897  0.166530     0.172198      0.170325  0.168435  0.174055
# 3   0.141013  0.149758     0.144473      0.146222  0.147984  0.142737
# 4   0.177210  0.169795     0.174268      0.172785  0.171294  0.175743
# 5   0.194365  0.193028     0.193835      0.193567  0.193298  0.194101
# 6   0.155969  0.161720     0.158255      0.159405  0.160560  0.157109
# 7   0.157948  0.159509     0.158569      0.158881  0.159194  0.158258
# 8   0.146957  0.148249     0.147471      0.147729  0.147989  0.147214
# 9   0.064634  0.065114     0.064825      0.064921  0.065017  0.064729
# 10  0.057802  0.057321     0.057610      0.057514  0.057418  0.057706
# 11  0.137837  0.134006     0.136310      0.135544  0.134776  0.137075
# 12  0.129804  0.130494     0.130079      0.130217  0.130355  0.129941
# 13  0.132844  0.131284     0.132222      0.131910  0.131598  0.132533
# 14  0.127637  0.126011     0.126988      0.126663  0.126337  0.127313
# 15  0.129302  0.129865     0.129527      0.129639  0.129752  0.129414
# 16  0.124196  0.127837     0.125649      0.126377  0.127106  0.124922
# 17  0.123108  0.120491     0.122063      0.121540  0.121016  0.122586
# 18  0.128910  0.129404     0.129107      0.129206  0.129305  0.129008
# 19  0.126410  0.128836     0.127378      0.127864  0.128350  0.126894
#
#      Chicago
# 0   0.253405
# 1   0.143305
# 2   0.164608
# 3   0.151546
# 4   0.168287
# 5   0.192756
# 6   0.162884
# 7   0.159825
# 8   0.148510
# 9   0.065210
# 10  0.057224
# 11  0.133234
# 12  0.130633
# 13  0.130971
# 14  0.125684
# 15  0.129978
# 16  0.128569
# 17  0.119965
# 18  0.129503
# 19  0.129324

# %%
target_cities = ["Miami",
                 "New York",
                 "Los Angeles",
                 "Philadelphia",
                 "Houston",
                 "Atlanta",
                 "Chicago"]


avg_list = []
for city in target_cities:
    avg_list.append(avg_sentiment[city].mean())

avg_list
# Out:
# [0.14235305581580054,
#  0.14146159915686823,
#  0.1420082399257202,
#  0.1418300721934997,
#  0.14164790155264728,
#  0.14218252829481656,
#  0.14127103057115872]

# %%
sns.set()
x_axis = np.arange(len(target_cities))
    
plt.figure(figsize = (25,10))    
    
    
sentiment_analysis = plt.bar(x_axis,
                             avg_list,
                             color = {"darkred"})

tick_locations = [value for value in x_axis]
tick_labels = target_cities
plt.xticks(tick_locations, tick_labels )
plt.ylim(0.165,0.169)
plt.xlabel("Cities")
plt.ylabel("Avg Compound Sentiment")
plt.title("City Sentiments of Restaurants Based on Twitter")

plt.savefig("City Sentiments of Restaurants Based on Twitter.png")

plt.show()
